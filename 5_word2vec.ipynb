# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %matplotlib inline

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'a', 'anarchism', 'originated', 'of', 'originated', 'as', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/adagrad.py:76: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.694069
# Nearest to more: padres, legendary, speculator, outgrowth, metrology, parentheses, additional, bi,
# Nearest to people: slowdown, they, fini, oas, affects, graeco, falsifiable, uruk,
# Nearest to who: giorgio, eras, tractatus, pharsalus, levels, warlords, paraphyletic, rushdie,
# Nearest to many: communicated, govern, lomond, breathing, frau, she, winston, rel,
# Nearest to of: chipset, vocabulary, chiaroscuro, van, andrade, terror, displeasure, peres,
# Nearest to had: dagobert, resurrect, apparel, hermaphroditus, promoted, randall, congolese, dogmatic,
# Nearest to a: romanticism, kenner, boziz, solves, confederates, flinders, cuzco, comforts,
# Nearest to that: jews, diaconate, chavez, bofors, bight, landsmannschaft, uncommonly, hillel,
# Nearest to be: venezuelan, incursions, bodybuilder, criticized, libyans, obesity, speedup, mallets,
# Nearest to s: gunships, minuscule, dramas, risen, incompatibilities, theorizes, poul, screenplay,
# Nearest to will: microstates, putin, bukem, strangers, router, freedmen, oaths, breaded,
# Nearest to i: sof, rented, lurking, borough, discerned, scheming, worsening, kj,
# Nearest to time: homeomorphic, haymarket, bombings, speyer, bulgaria, discerning, fool, normale,
# Nearest to were: unsatisfactory, radioactive, bai, caltech, worms, dara, velde, exhibiting,
# Nearest to these: iud, butterflies, hackman, childe, gonz, finkel, manoel, cursed,
# Nearest to years: analogously, mentats, arms, adults, valium, inspired, checkmate, russification,
# Average loss at step 2000: 4.372505
# Average loss at step 4000: 3.872543
# Average loss at step 6000: 3.798679
# Average loss at step 8000: 3.689025
# Average loss at step 10000: 3.616070
# Nearest to more: ut, bi, speculator, bridal, most, less, loops, nicky,
# Nearest to people: they, delusion, remarks, falsifiable, unemployment, revolutionaries, slowdown, judit,
# Nearest to who: he, they, also, masons, thessalonians, and, simplifies, sedentary,
# Nearest to many: these, psalms, some, odi, governs, compl, lomond, ordinate,
# Nearest to of: in, pathology, for, sutcliffe, dubai, doctorate, or, judaizers,
# Nearest to had: has, was, have, blunder, were, is, suggested, aptitude,
# Nearest to a: the, cnd, supranational, barron, ean, ec, capybara, stefan,
# Nearest to that: which, this, distribution, it, jews, same, they, anne,
# Nearest to be: have, was, aetius, been, prut, is, neck, tutoring,
# Nearest to s: and, his, usda, widgets, attestation, supremacy, vite, nadu,
# Nearest to will: would, recognises, putin, can, to, microstates, tarkovsky, bukem,
# Nearest to i: ethnic, hylas, gould, dialects, grasso, kazantzakis, aggressor, staining,
# Nearest to time: fledged, homeomorphic, bombings, fool, haymarket, types, features, docks,
# Nearest to were: are, was, have, pentastar, arthur, hercule, by, had,
# Nearest to these: many, iud, periphery, donner, shielding, named, poet, aisle,
# Nearest to years: cranberry, inspired, tracked, sig, valium, taxing, arms, prohibiting,
# Average loss at step 12000: 3.603970
# Average loss at step 14000: 3.569251
# Average loss at step 16000: 3.405518
# Average loss at step 18000: 3.456674
# Average loss at step 20000: 3.539333
# Nearest to more: less, most, speculator, bi, ut, loops, slight, essayists,
# Nearest to people: granitic, slowdown, unemployment, delusion, moreover, revolutionaries, zwicker, focus,
# Nearest to who: he, they, which, also, often, desiderius, sedentary, paracetamol,
# Nearest to many: some, several, these, other, all, such, ordinate, governs,
# Nearest to of: for, in, pathology, gauntlet, nowak, ghz, seaport, divinities,
# Nearest to had: has, have, was, were, curbed, frontline, been, sintering,
# Nearest to a: another, the, supranational, ean, ec, cnd, ezra, sprang,
# Nearest to that: which, this, but, boxers, chavez, when, distribution, bofors,
# Nearest to be: have, been, archaeopteryx, being, tutoring, prut, by, make,
# Nearest to s: johan, alexius, fredericksburg, asgard, nas, commercial, milestones, niggers,
# Nearest to will: would, could, can, should, may, might, shatt, must,
# Nearest to i: ii, ethnic, we, they, kazantzakis, hans, fable, hylas,
# Nearest to time: fledged, year, features, process, juno, bombings, homeomorphic, fp,
# Nearest to were: are, was, had, have, being, by, sanger, be,
# Nearest to these: many, some, such, other, they, which, several, those,
# Nearest to years: florian, taxing, tracked, ville, valium, entre, analogously, southwest,
# Average loss at step 22000: 3.501621
# Average loss at step 24000: 3.486136
# Average loss at step 26000: 3.482783
# Average loss at step 28000: 3.481477
# Average loss at step 30000: 3.502565
# Nearest to more: less, most, greater, bi, speculator, dictates, very, loops,
# Nearest to people: unemployment, reawakened, remarks, granitic, children, patients, individuals, dakar,
# Nearest to who: he, they, which, also, it, often, and, sedentary,
# Nearest to many: some, several, these, all, such, those, their, both,
# Nearest to of: in, from, gath, ite, cv, and, pesos, reassured,
# Nearest to had: has, have, was, were, suggested, having, when, is,
# Nearest to a: any, the, no, sprang, cnd, this, ec, doo,
# Nearest to that: which, this, however, longshanks, but, oils, what, where,
# Nearest to be: have, been, is, prut, were, archaeopteryx, was, being,
# Nearest to s: his, vite, longbows, did, whose, her, pogues, pears,
# Nearest to will: would, can, could, may, should, must, might, shatt,
# Nearest to i: ii, we, they, you, walnut, t, massed, staining,
# Nearest to time: year, fledged, features, process, juno, bombings, country, shorelines,
# Nearest to were: are, was, had, have, is, sanger, wf, being,
# Nearest to these: many, some, several, they, such, their, different, which,
# Nearest to years: months, days, year, times, florian, however, taxing, tracked,
# Average loss at step 32000: 3.497887
# Average loss at step 34000: 3.497723
# Average loss at step 36000: 3.454375
# Average loss at step 38000: 3.300148
# Average loss at step 40000: 3.431527
# Nearest to more: less, most, greater, very, speculator, superman, loops, routine,
# Nearest to people: reawakened, unemployment, judit, zwicker, remarks, individuals, children, languages,
# Nearest to who: often, he, which, also, they, desiderius, there, injustices,
# Nearest to many: some, several, these, those, both, various, all, such,
# Nearest to of: in, from, for, signifies, ghz, eth, divinities, pesos,
# Nearest to had: has, have, was, were, been, suggested, having, subsequently,
# Nearest to a: another, the, cnd, any, trip, horizontally, no, weakness,
# Nearest to that: which, this, what, however, where, oils, counsellor, often,
# Nearest to be: have, been, is, was, are, prut, were, being,
# Nearest to s: did, vite, his, holyrood, balderus, rarer, freyja, predefined,
# Nearest to will: would, can, could, may, must, should, might, cannot,
# Nearest to i: ii, we, you, they, t, outdoors, he, walnut,
# Nearest to time: year, fledged, way, juno, process, shorelines, country, fp,
# Nearest to were: are, have, was, had, be, clavichord, being, wf,
# Nearest to these: many, some, several, they, different, such, both, there,
# Nearest to years: days, months, times, year, hours, however, tracked, florian,
# Average loss at step 42000: 3.436530
# Average loss at step 44000: 3.453204
# Average loss at step 46000: 3.454426
# Average loss at step 48000: 3.357562
# Average loss at step 50000: 3.387540
# Nearest to more: less, most, very, highly, greater, zanetti, relatively, too,
# Nearest to people: children, men, reawakened, chobert, herring, zwicker, years, signer,
# Nearest to who: he, which, they, often, injustices, disconcerting, she, there,
# Nearest to many: some, several, these, both, those, various, certain, such,
# Nearest to of: in, and, nowak, including, ghz, for, reassured, suleiman,
# Nearest to had: has, have, was, having, suggested, were, been, already,
# Nearest to a: another, the, cnd, hammett, musicianship, doo, supranational, any,
# Nearest to that: which, however, what, chavez, this, bofors, but, oils,
# Nearest to be: have, was, were, been, ergodic, being, tutoring, is,
# Nearest to s: vite, commutation, lamellar, brochs, did, whose, his, auditioned,
# Nearest to will: would, can, could, may, must, should, might, cannot,
# Nearest to i: we, ii, you, t, outdoors, kj, gray, they,
# Nearest to time: year, way, econometric, rca, superstars, day, process, abrasion,
# Nearest to were: are, was, have, be, been, had, being, dap,
# Nearest to these: several, some, many, both, such, they, those, installs,
# Nearest to years: days, months, times, year, hours, people, florian, period,
# Average loss at step 52000: 3.439639
# Average loss at step 54000: 3.425808
# Average loss at step 56000: 3.434979
# Average loss at step 58000: 3.396923
# Average loss at step 60000: 3.392188
# Nearest to more: less, most, very, greater, too, essayists, rather, highly,
# Nearest to people: men, children, reawakened, zwicker, years, writers, chobert, maude,
# Nearest to who: he, which, still, often, disconcerting, never, already, she,
# Nearest to many: some, several, these, various, most, such, both, other,
# Nearest to of: in, for, same, like, forcible, thoughtful, liters, eluded,
# Nearest to had: has, have, was, were, having, been, never, lost,
# Nearest to a: another, any, the, cnd, this, horizontally, every, no,
# Nearest to that: which, what, however, this, currently, oils, longships, where,
# Nearest to be: been, tutoring, have, was, ergodic, become, is, being,
# Nearest to s: vite, lamellar, gadol, predefined, fosters, himalaya, pogues, usn,
# Nearest to will: would, could, can, may, should, must, might, does,
# Nearest to i: ii, we, you, t, they, kj, outdoors, walnut,
# Nearest to time: year, econometric, process, way, shorelines, juno, superstars, fledged,
# Nearest to were: are, was, had, have, although, including, been, those,
# Nearest to these: many, some, several, those, they, such, both, which,
# Nearest to years: days, months, times, hours, year, weeks, people, decades,
# Average loss at step 62000: 3.241131
# Average loss at step 64000: 3.261429
# Average loss at step 66000: 3.401924
# Average loss at step 68000: 3.394161
# Average loss at step 70000: 3.358494
# Nearest to more: less, most, very, too, greater, highly, relatively, other,
# Nearest to people: men, children, maude, writers, members, zwicker, copies, women,
# Nearest to who: he, which, desiderius, masons, ref, still, chez, mislead,
# Nearest to many: some, several, these, various, most, other, both, those,
# Nearest to of: including, for, although, like, and, in, dunbar, or,
# Nearest to had: has, have, was, were, having, sightseeing, cessna, suggested,
# Nearest to a: the, another, any, cnd, doo, barron, taxicab, hammett,
# Nearest to that: which, however, what, this, but, where, often, bolshevist,
# Nearest to be: been, is, become, being, tutoring, were, was, ergodic,
# Nearest to s: whose, salads, fosters, rarer, vite, aloe, wesley, seismic,
# Nearest to will: would, could, can, may, should, must, might, cannot,
# Nearest to i: ii, we, you, outdoors, yd, g, walnut, t,
# Nearest to time: year, econometric, process, way, juno, shorelines, invaders, bedrock,
# Nearest to were: are, was, have, had, be, these, those, been,
# Nearest to these: many, some, such, several, those, the, their, are,
# Nearest to years: days, months, hours, year, times, decades, weeks, minutes,
# Average loss at step 72000: 3.376871
# Average loss at step 74000: 3.346645
# Average loss at step 76000: 3.317340
# Average loss at step 78000: 3.352733
# Average loss at step 80000: 3.381683
# Nearest to more: less, very, most, greater, too, quite, relatively, larger,
# Nearest to people: men, children, women, writers, copies, individuals, jews, maude,
# Nearest to who: he, mislead, often, ref, they, still, injustices, she,
# Nearest to many: some, several, various, these, most, both, numerous, those,
# Nearest to of: including, in, ghz, bothered, nowak, original, forcible, fatalities,
# Nearest to had: have, has, were, was, having, been, never, began,
# Nearest to a: another, doo, supranational, every, legitimately, the, defying, hammett,
# Nearest to that: which, however, what, courtesy, where, this, currently, chavez,
# Nearest to be: been, have, being, become, tutoring, ergodic, easily, were,
# Nearest to s: isbn, az, whose, wesley, zebulon, vite, steve, seismic,
# Nearest to will: would, could, can, may, should, must, might, cannot,
# Nearest to i: ii, you, we, g, oscilloscope, outdoors, iii, t,
# Nearest to time: year, juno, econometric, way, fledged, superstars, cheque, medication,
# Nearest to were: are, had, was, have, been, being, be, those,
# Nearest to these: several, many, those, some, such, both, various, they,
# Nearest to years: days, months, times, hours, year, decades, weeks, minutes,
# Average loss at step 82000: 3.406754
# Average loss at step 84000: 3.411131
# Average loss at step 86000: 3.392575
# Average loss at step 88000: 3.350245
# Average loss at step 90000: 3.363372
# Nearest to more: less, very, greater, most, too, quite, extremely, highly,
# Nearest to people: children, men, jews, women, writers, members, individuals, maude,
# Nearest to who: he, often, she, but, which, mislead, still, also,
# Nearest to many: some, several, these, various, most, all, numerous, both,
# Nearest to of: including, in, for, during, from, genitalia, and, respiratory,
# Nearest to had: has, have, was, were, having, since, began, came,
# Nearest to a: another, the, doo, any, melinda, every, supranational, forester,
# Nearest to that: which, however, what, but, auvergne, courtesy, why, simplifies,
# Nearest to be: been, was, become, ergodic, have, is, being, achieve,
# Nearest to s: isbn, whose, his, salads, brochs, vite, oaxaca, holyrood,
# Nearest to will: would, could, can, may, must, might, should, cannot,
# Nearest to i: we, ii, g, you, oscilloscope, t, k, walnut,
# Nearest to time: year, juno, day, cheque, hobsbawm, fledged, abrasion, way,
# Nearest to were: are, was, had, have, been, those, although, while,
# Nearest to these: several, many, some, such, are, those, which, both,
# Nearest to years: days, months, hours, decades, year, times, minutes, weeks,
# Average loss at step 92000: 3.397958
# Average loss at step 94000: 3.255142
# Average loss at step 96000: 3.357753
# Average loss at step 98000: 3.242562
# Average loss at step 100000: 3.355197
# Nearest to more: less, very, most, greater, quite, relatively, too, extremely,
# Nearest to people: children, jews, men, women, individuals, writers, citizens, members,
# Nearest to who: he, she, never, still, nor, mislead, which, often,
# Nearest to many: several, some, these, various, numerous, few, those, all,
# Nearest to of: including, in, bothered, original, forcible, entire, emb, and,
# Nearest to had: has, have, was, since, were, having, detects, never,
# Nearest to a: another, the, any, defying, doo, barron, melinda, cnd,
# Nearest to that: which, however, what, actually, often, unregistered, when, who,
# Nearest to be: been, being, have, ergodic, become, is, are, easily,
# Nearest to s: his, whose, balderus, wesley, seismic, az, semitones, isbn,
# Nearest to will: would, could, can, must, should, may, might, cannot,
# Nearest to i: we, you, ii, they, oscilloscope, adrian, t, rz,
# Nearest to time: year, day, hobsbawm, way, process, fledged, abrasion, juno,
# Nearest to were: are, have, these, was, those, had, although, include,
# Nearest to these: several, some, many, various, all, such, were, those,
# Nearest to years: days, months, hours, decades, times, year, minutes, weeks,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
    global data_index
    
    span = 2 * bag_window + 1
    
    batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    
    buffer = collections.deque(maxlen=span)
    
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
        
    for i in range(batch_size):
        target_index = span // 2
        source_index = np.random.permutation(np.setdiff1d(np.arange(span), target_index))
        
        batch[i] = [buffer[i] for i in source_index]
        labels[i] = buffer[target_index]
        
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
        
    return batch, labels

# %%
for bag_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(8, bag_window)
    
    print("\ndata:", [reverse_dictionary[di] for di in data[:8]])
    print("Batch", [[reverse_dictionary[w] for w in bi] for bi in batch])
    print("Labels", [reverse_dictionary[l] for l in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
# Batch [['as', 'anarchism'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['abuse', 'term'], ['of', 'first'], ['abuse', 'used'], ['against', 'first']]
# Labels ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
# Batch [['originated', 'anarchism', 'a', 'term'], ['as', 'originated', 'of', 'term'], ['abuse', 'as', 'of', 'a'], ['term', 'first', 'abuse', 'a'], ['used', 'first', 'term', 'of'], ['abuse', 'against', 'used', 'of'], ['against', 'abuse', 'first', 'early'], ['early', 'used', 'working', 'first']]
# Labels ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
bag_window =  2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embed, 1),
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
            batch_size, bag_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.854924
# Nearest to for: aron, mckean, tempting, vaccines, soldier, dogg, sinful, advertising,
# Nearest to that: overcomes, espace, indexed, dragoon, addressee, jadwiga, commissars, independently,
# Nearest to two: advertise, xerox, kayak, lawmakers, irvine, hutchinson, answered, restraining,
# Nearest to states: greenhouse, biochemists, rohrabacher, supercharger, relationships, gauthier, witt, derails,
# Nearest to after: morrow, relativism, muscat, crossbows, abeokuta, disambiguate, oktoberfest, parc,
# Nearest to seven: judi, lacanian, shepherd, valeria, decreed, beginning, morava, gumby,
# Nearest to called: melting, chiapas, evenly, erythematosus, marie, islam, shredded, strontium,
# Nearest to during: vaccines, beans, franjo, janos, mil, fatwa, instead, solvents,
# Nearest to has: suny, colloquially, circulates, arched, derleth, idempotent, storing, dub,
# Nearest to at: cryobiology, elements, kennings, section, bootlegs, stupid, microkernels, buoyancy,
# Nearest to zero: risings, robert, stilgar, fabulous, quan, mysteriously, idempotents, reindeer,
# Nearest to some: bikini, castration, electrophoresis, penalties, sanctioned, students, gaku, guzm,
# Nearest to which: kyd, coin, shining, nasl, adaptable, tamil, explainable, omnipotence,
# Nearest to and: ip, masefield, identifications, dmitry, cuvier, undergo, according, booksellers,
# Nearest to but: xcd, memphis, auditions, sheltering, softness, oise, gahan, altogether,
# Nearest to war: slurred, quarterback, venezuelan, dandyism, testes, revealed, lez, filtration,
# Average loss at step 2000: 4.604642
# Average loss at step 4000: 3.943379
# Average loss at step 6000: 3.728879
# Average loss at step 8000: 3.527712
# Average loss at step 10000: 3.481017
# Nearest to for: of, lapd, imagining, duesberg, christophe, through, characterisation, coleman,
# Nearest to that: which, who, reversal, when, this, achieve, domineering, what,
# Nearest to two: zero, three, four, six, five, eight, comment, suppressing,
# Nearest to states: kingdom, fdi, coup, supercharger, longed, nations, orchid, mercantilist,
# Nearest to after: during, before, vardar, uf, sibley, chobert, when, challenging,
# Nearest to seven: nine, six, eight, three, five, four, zero, ulyanov,
# Nearest to called: haight, chiapas, used, considered, landon, proposed, evenly, brett,
# Nearest to during: after, in, resist, against, sitcom, charing, around, silverman,
# Nearest to has: had, have, is, having, was, interrupting, retorted, tiki,
# Nearest to at: polemic, fukuda, irda, cryobiology, cenozoic, spices, aviv, from,
# Nearest to zero: five, four, two, eight, three, nine, six, seven,
# Nearest to some: many, any, several, most, marta, giant, these, propagation,
# Nearest to which: that, this, it, who, what, there, tony, townsend,
# Nearest to and: or, including, miniaturization, siddur, yaqub, diploid, but, american,
# Nearest to but: however, crimean, because, substituents, and, dart, although, figuratively,
# Nearest to war: berth, necronomicon, contrabass, scarcely, trance, hbo, bun, quarterback,
# Average loss at step 12000: 3.496140
# Average loss at step 14000: 3.435054
# Average loss at step 16000: 3.436073
# Average loss at step 18000: 3.404891
# Average loss at step 20000: 3.217626
# Nearest to for: after, lapd, complaints, informants, including, invite, allyn, bara,
# Nearest to that: which, what, where, this, however, who, although, how,
# Nearest to two: three, five, nine, zero, four, eight, contour, mandrakesoft,
# Nearest to states: kingdom, nations, fdi, intend, mercantilist, longed, tapes, state,
# Nearest to after: before, during, for, gumby, parc, through, when, mongol,
# Nearest to seven: five, six, eight, three, nine, four, zero, gob,
# Nearest to called: used, known, there, considered, silesian, chiapas, politican, capricious,
# Nearest to during: in, after, over, against, before, through, since, under,
# Nearest to has: had, have, having, is, tiki, was, slurred, idempotent,
# Nearest to at: mitochondrion, cthulhu, captained, during, pneumoniae, hideous, resting, reconcile,
# Nearest to zero: five, seven, eight, nine, three, six, four, two,
# Nearest to some: many, several, certain, these, both, any, most, various,
# Nearest to which: that, this, cryptographic, spliced, what, often, who, where,
# Nearest to and: or, while, but, storytelling, although, fisch, cowardice, like,
# Nearest to but: however, although, while, and, though, among, sweeteners, langford,
# Nearest to war: espoo, niches, trance, contrabass, interrogated, rana, uber, impartiality,
# Average loss at step 22000: 3.355279
# Average loss at step 24000: 3.288768
# Average loss at step 26000: 3.261236
# Average loss at step 28000: 3.283286
# Average loss at step 30000: 3.227955
# Nearest to for: during, after, before, guerra, complaints, maximin, cranial, imagining,
# Nearest to that: which, this, corum, however, where, who, cohesive, what,
# Nearest to two: six, three, gimel, freas, five, several, eight, decolonization,
# Nearest to states: kingdom, nations, fdi, intend, countries, mercantilist, longed, friday,
# Nearest to after: before, during, since, through, for, until, from, monographs,
# Nearest to seven: eight, nine, six, four, five, zero, three, apollo,
# Nearest to called: used, considered, known, politican, see, substandard, named, petrochemical,
# Nearest to during: after, before, throughout, norwegians, through, in, at, under,
# Nearest to has: had, have, having, is, contains, teamwork, was, gives,
# Nearest to at: during, from, until, frey, in, before, norwegians, mitochondrion,
# Nearest to zero: eight, five, six, nine, million, four, seven, th,
# Nearest to some: many, several, most, these, all, numerous, various, certain,
# Nearest to which: that, what, this, where, born, acceptability, when, spliced,
# Nearest to and: including, while, with, or, like, comet, although, assertions,
# Nearest to but: however, see, than, unobstructed, though, while, like, tos,
# Nearest to war: contrabass, espoo, rana, uber, synchronize, valentinians, wondrous, days,
# Average loss at step 32000: 3.012546
# Average loss at step 34000: 3.209573
# Average loss at step 36000: 3.197690
# Average loss at step 38000: 3.151775
# Average loss at step 40000: 3.162521
# Nearest to for: including, after, during, although, craggy, episcopate, cranial, in,
# Nearest to that: which, however, although, this, thus, ayyubid, ultraviolet, christo,
# Nearest to two: three, five, six, several, nine, four, zero, overlordship,
# Nearest to states: kingdom, nations, naturalized, fdi, fabricate, haganah, longed, lycus,
# Nearest to after: before, during, despite, while, following, until, when, since,
# Nearest to seven: six, eight, five, four, nine, three, zero, two,
# Nearest to called: considered, known, used, unlucky, see, named, hybridization, awarded,
# Nearest to during: after, throughout, in, norwegians, since, despite, before, through,
# Nearest to has: had, have, having, is, includes, was, makes, contains,
# Nearest to at: during, lucas, huac, hideous, gonna, between, mitochondrion, until,
# Nearest to zero: eight, six, five, four, seven, million, nine, three,
# Nearest to some: many, several, various, both, most, these, certain, numerous,
# Nearest to which: that, where, what, this, also, remarry, octave, located,
# Nearest to and: or, while, including, although, siddur, however, where, causing,
# Nearest to but: although, however, while, than, though, see, irritability, and,
# Nearest to war: espoo, wars, contrabass, sharon, berth, bryson, rana, satrapy,
# Average loss at step 42000: 3.206671
# Average loss at step 44000: 3.141835
# Average loss at step 46000: 3.138831
# Average loss at step 48000: 3.056457
# Average loss at step 50000: 3.080677
# Nearest to for: without, bowman, including, maximin, of, after, rides, when,
# Nearest to that: which, however, although, where, translucent, what, whereas, when,
# Nearest to two: five, three, eight, four, seven, six, nine, one,
# Nearest to states: kingdom, nations, naturalized, implications, fdi, longed, mercantilist, resignation,
# Nearest to after: before, during, without, following, until, despite, through, from,
# Nearest to seven: eight, six, five, nine, four, three, zero, two,
# Nearest to called: used, named, known, considered, diabetics, termed, crookes, analysed,
# Nearest to during: throughout, in, after, since, around, norwegians, before, until,
# Nearest to has: had, have, having, contains, is, vcr, requires, includes,
# Nearest to at: near, kuro, marines, in, jackals, cenozoic, lucas, during,
# Nearest to zero: five, eight, three, seven, four, nine, six, bc,
# Nearest to some: many, several, numerous, various, these, thousands, all, certain,
# Nearest to which: that, where, this, what, mung, implant, who, often,
# Nearest to and: or, while, including, but, although, bootlegs, ricci, polisario,
# Nearest to but: although, though, than, while, and, however, dso, litigated,
# Nearest to war: wars, berth, rana, importance, bryson, reign, revolution, charlottetown,
# Average loss at step 52000: 3.089993
# Average loss at step 54000: 3.095122
# Average loss at step 56000: 2.918987
# Average loss at step 58000: 3.018383
# Average loss at step 60000: 3.051088
# Nearest to for: maximin, without, after, remit, ralston, coy, characterisation, tyndale,
# Nearest to that: which, however, what, where, who, how, reticulum, when,
# Nearest to two: five, four, six, three, zero, nine, eight, several,
# Nearest to states: kingdom, nations, fdi, claims, mercantilist, provinces, countries, birdman,
# Nearest to after: before, despite, during, following, without, when, afterwards, mongol,
# Nearest to seven: eight, six, five, nine, four, three, zero, temperaments,
# Nearest to called: considered, used, termed, named, diabetics, held, described, produced,
# Nearest to during: throughout, in, after, merrimack, before, since, norwegians, despite,
# Nearest to has: had, have, having, is, contains, was, includes, vcr,
# Nearest to at: near, during, hideous, in, glow, cenozoic, frey, huac,
# Nearest to zero: five, eight, seven, six, four, three, nine, million,
# Nearest to some: many, several, various, numerous, most, thousands, all, few,
# Nearest to which: that, what, this, where, involved, who, implant, yamamoto,
# Nearest to and: but, although, or, than, while, including, however, exhorted,
# Nearest to but: although, though, than, however, and, while, vhdl, obscene,
# Nearest to war: wars, revolution, espoo, contrabass, causality, federation, undetected, chisinau,
# Average loss at step 62000: 3.015552
# Average loss at step 64000: 2.923886
# Average loss at step 66000: 2.933854
# Average loss at step 68000: 2.969058
# Average loss at step 70000: 3.017434
# Nearest to for: after, without, rides, allyn, when, characterisation, undamaged, remit,
# Nearest to that: which, what, this, however, where, devito, although, reticulum,
# Nearest to two: three, seven, five, six, zero, eight, four, maximally,
# Nearest to states: kingdom, nations, fdi, sculpture, provinces, conquests, churches, ironically,
# Nearest to after: before, during, despite, for, without, following, when, within,
# Nearest to seven: six, five, three, eight, four, two, zero, nine,
# Nearest to called: considered, used, known, termed, named, held, found, joined,
# Nearest to during: throughout, in, after, before, despite, at, norwegians, against,
# Nearest to has: had, have, having, is, contains, gives, includes, makes,
# Nearest to at: near, during, calif, in, around, juli, vivian, reached,
# Nearest to zero: five, two, three, seven, eight, million, six, unwieldy,
# Nearest to some: many, several, numerous, all, certain, these, various, thousands,
# Nearest to which: that, where, what, this, but, majdanek, when, although,
# Nearest to and: or, but, including, while, although, baserunners, vtol, however,
# Nearest to but: though, although, and, however, because, which, while, sturdy,
# Nearest to war: wars, past, causality, aldous, bryson, conflict, north, revolution,
# Average loss at step 72000: 2.941415
# Average loss at step 74000: 2.860147
# Average loss at step 76000: 3.001855
# Average loss at step 78000: 3.008160
# Average loss at step 80000: 2.847597
# Nearest to for: without, maximin, juanita, jus, dez, when, after, mathias,
# Nearest to that: which, what, however, how, gaucho, where, whereas, this,
# Nearest to two: three, four, six, seven, one, nine, nashe, moshoeshoe,
# Nearest to states: kingdom, nations, fdi, provinces, churches, birdman, claims, fabricate,
# Nearest to after: before, following, during, despite, when, since, thurston, cozy,
# Nearest to seven: six, eight, four, five, three, nine, zero, two,
# Nearest to called: named, used, termed, considered, known, described, substandard, joined,
# Nearest to during: throughout, before, since, norwegians, after, in, despite, merrimack,
# Nearest to has: had, have, having, contains, is, includes, was, identifies,
# Nearest to at: near, during, towards, hideous, mitochondrion, toward, in, bowser,
# Nearest to zero: five, seven, eight, six, nine, four, million, three,
# Nearest to some: many, several, numerous, both, all, certain, most, various,
# Nearest to which: that, what, this, who, these, whose, bootlegs, where,
# Nearest to and: or, including, etc, but, include, galil, vtol, bootlegs,
# Nearest to but: though, however, although, and, while, see, because, which,
# Nearest to war: wars, foil, contrabass, perennial, champion, conflict, tama, submarine,
# Average loss at step 82000: 2.942747
# Average loss at step 84000: 2.896692
# Average loss at step 86000: 2.924062
# Average loss at step 88000: 2.943251
# Average loss at step 90000: 2.831201
# Nearest to for: jus, including, emptive, maximin, thien, rides, allyn, examiner,
# Nearest to that: which, what, where, when, because, whereas, reticulum, montrose,
# Nearest to two: three, six, four, dhyana, five, seven, nine, vit,
# Nearest to states: kingdom, nations, provinces, fdi, claims, barber, sculpture, stated,
# Nearest to after: before, despite, during, following, thereafter, when, until, since,
# Nearest to seven: six, eight, four, five, nine, three, zero, one,
# Nearest to called: named, considered, known, termed, used, described, joined, required,
# Nearest to during: throughout, after, before, in, despite, until, since, merrimack,
# Nearest to has: had, have, contains, having, includes, is, was, gives,
# Nearest to at: near, during, towards, bowser, mitochondrion, hideous, cryobiology, huac,
# Nearest to zero: eight, five, six, seven, million, nine, four, three,
# Nearest to some: many, several, numerous, certain, most, various, both, multiple,
# Nearest to which: that, what, this, where, who, also, spliced, bootlegs,
# Nearest to and: or, including, while, etc, but, curie, nor, macquarie,
# Nearest to but: however, though, although, siddha, see, and, unlike, ricci,
# Nearest to war: wars, driest, foil, perennial, understand, niches, angola, rana,
# Average loss at step 92000: 2.897444
# Average loss at step 94000: 2.876376
# Average loss at step 96000: 2.713489
# Average loss at step 98000: 2.453952
# Average loss at step 100000: 2.711933
# Nearest to for: after, emptive, maximin, remit, allyn, koyaanisqatsi, despite, guerra,
# Nearest to that: which, where, however, although, dervish, whereas, whom, who,
# Nearest to two: four, three, five, seven, six, eight, nine, decolonization,
# Nearest to states: kingdom, nations, state, resignation, nouveaux, provinces, countries, sil,
# Nearest to after: before, despite, following, without, for, upon, afterwards, thereafter,
# Nearest to seven: five, six, eight, four, three, nine, zero, two,
# Nearest to called: named, termed, considered, known, joined, used, described, required,
# Nearest to during: throughout, in, despite, through, merrimack, at, until, around,
# Nearest to has: had, have, having, contains, includes, is, gives, was,
# Nearest to at: near, during, in, around, after, outside, fathoms, highest,
# Nearest to zero: five, eight, six, four, seven, million, three, nine,
# Nearest to some: many, several, numerous, various, most, certain, both, all,
# Nearest to which: that, where, also, this, who, typically, what, usually,
# Nearest to and: or, but, etc, while, including, though, although, however,
# Nearest to but: however, though, and, although, or, while, than, until,
# Nearest to war: wars, speaking, foil, bormann, tama, cup, bryson, naia,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
